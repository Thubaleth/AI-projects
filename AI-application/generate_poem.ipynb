# %%
import os 
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv()
Api_key = os.getenv("OpenAi_API_key")

# %%
def get_response(prompt):
    client = OpenAI(api_key=Api_key)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        max_completion_tokens=100,
        messages = [
            {"role":"user","content":prompt}
            ]

    )
    return response.choices[0].message.content

# %%
prompt = "generate a poem about ChatGPT while ensuring that it is written in basic English that a child can understand."

response = get_response(prompt)

print(response)
# Out:
# In a world of words, bright and clear,
# ChatGPT is always near.
# With questions asked, both big and small,
# It tries its best to help us all.
#
# With stories, facts, or jokes that cheer,
# Just type them out, and it will hear.
# From morning light to evening's glow,
# ChatGPT is here to grow!
#
# It's like a friend who knows so much,
# With every answer, every touch.
# So if you're curious and
