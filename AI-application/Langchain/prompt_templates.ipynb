# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# %%
load_dotenv()
Api_key = os.getenv("OpenAi_API_key")

# %%
#prompt template
template = """
You are an artificial intellegence assistant.
Answer the following question 
{question}
"""

prompt = PromptTemplate.from_template(template)

# %%
#create model
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=Api_key 
)

llm_chain = prompt | llm

# %%
#invoke chain
question = "How does LangChain make LLM application development easier?"

response = llm_chain.invoke({
    "question" : question
})

# %%
print(response.content)
# Out:
# LangChain is a framework designed specifically to simplify the development of applications that leverage large language models (LLMs). Here are several ways in which LangChain facilitates LLM application development:
#
# 1. **Modular Components**: LangChain provides a set of modular components that developers can easily mix and match. This includes tools for prompt management, memory handling, chains, and agents, which allows for flexible building of applications tailored to specific needs.
#
# 2. **Chains**: It enables the creation of "chains" which are sequences of calls that can be configured to pass information between different components. This allows developers to build complex workflows by combining various LLM functionalities in a structured way.
#
# 3. **Prompt Management**: LangChain offers utilities for managing prompts, including templates and dynamic prompt creation. This helps developers efficiently design and reuse prompts, making it easier to create consistent and effective user interactions.
#
# 4. **Integrations**: The framework supports integration with various APIs, databases, and vector stores, which allows for more sophisticated applications that can access external data sources and enhance the LLM's capabilities.
#
# 5. **Memory Management**: LangChain includes features for managing conversational memory, enabling applications to maintain context over multiple interactions. This allows for richer and more personalized user experiences.
#
# 6. **Testing and Debugging**: The framework is designed with development in mind, offering tools that facilitate testing and debugging of LLM applications, helping developers iterate more quickly and efficiently.
#
# 7. **Community and Documentation**: LangChain has an active community and extensive documentation, making it easier for developers to find support, share ideas, and access a wealth of resources and examples.
#
# 8. **Use Case-Specific Functionality**: LangChain includes examples and templates for various use cases, such as chatbots, question-answering systems, and data analysis tools. This helps developers get started quickly with the specific type of application they wish to build.
#
# By providing these features and tools, LangChain streamlines the development process, allowing developers to focus on building innovative applications leveraging the power of LLMs without getting bogged down by the complexities of handling the language model interactions directly.
