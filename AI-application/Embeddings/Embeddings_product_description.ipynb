# %%
"""An OpenAI client has already been created as assigned to `client`.

**Instructions**

- Create a list called `product_descriptions` containing the `'short_description'` for each product in `products` using a list comprehension.
- Create embeddings for each product `'short_description'` using **batching**, passing the input to the `text-embedding-3-small` model.
- Extract the embeddings for each product from `response_dict` and store them in `products` under a new key called `'embedding'`."""
# Out:
# "An OpenAI client has already been created as assigned to\xa0`client`.\n\n**Instructions**\n\n- Create a list called\xa0`product_descriptions`\xa0containing the\xa0`'short_description'`\xa0for each product in\xa0`products`\xa0using a list comprehension.\n- Create embeddings for each product\xa0`'short_description'`\xa0using\xa0**batching**, passing the input to the\xa0`text-embedding-3-small`\xa0model.\n- Extract the embeddings for each product from\xa0`response_dict`\xa0and store them in\xa0`products`\xa0under a new key called\xa0`'embedding'`."

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
load_dotenv()
# Out:
# True

# %%
products = [
    {
        "title": "Smartphone X1",
        "short_description": "The latest flagship smartphone with AI-powered features and 5G connectivity.",
        "price": 799.99,
        "category": "Electronics",
        "features": [
            "6.5-inch AMOLED display",
            "Quad-camera system with 48MP main sensor",
            "Face recognition and fingerprint sensor",
            "Fast wireless charging"
        ]
    }
    
]

# %%
# Extract a list of product short descriptions from products
product_description = [product["short_description"] for product in products]
print(product_description)
# Out:
# ['The latest flagship smartphone with AI-powered features and 5G connectivity.']

# %%
Api_key = os.getenv("OpenAi_API_key")
client = OpenAI(api_key=Api_key)

response = client.embeddings.create(
model="text-embedding-3-small",
input=product_description
    
)

response_dict = response.model_dump()
print(response_dict)
# Out:
# {'data': [{'embedding': [0.01690673828125, -0.01277923583984375, -0.0228424072265625, 0.02178955078125, 0.013763427734375, -0.0016632080078125, 0.0136871337890625, 0.037017822265625, 0.0321044921875, -0.01251220703125, -0.04058837890625, -0.033203125, -0.06597900390625, -0.0638427734375, -0.031280517578125, -0.047515869140625, -0.07537841796875, 0.002605438232421875, 0.0640869140625, -0.01116180419921875, -0.0257720947265625, 0.00353240966796875, 0.029876708984375, -0.01403045654296875, -0.0009860992431640625, -0.029327392578125, -0.0638427734375, 0.020111083984375, 0.0175018310546875, 0.0185089111328125, 0.01511383056640625, -0.0411376953125, 0.037353515625, -0.0108184814453125, -0.02044677734375, 0.0010833740234375, 0.011474609375, -0.040618896484375, -0.033905029296875, 0.034698486328125, 0.01152801513671875, 0.042236328125, 0.0146636962890625, 0.021728515625, -0.0240478515625, 0.002300262451171875, 0.0115966796875, -0.03363037109375, -0.0015878677368164062, 0.02581787109375, -0.0002130270004272461, -0.042510986328125, 0.0005779266357421875, 0.0298614501953125, -0.0185089111328125, 0.001556396484375, 0.051177978515625, 0.013763427734375, 0.033416748046875, 0.01611328125, -0.02947998046875, -0.00962066650390625, -0.0018644332885742188, -0.01146697998046875, -0.01415252685546875, -0.030242919921875, 0.0015096664428710938, 0.04620361328125, -0.032012939453125, -0.0204315185546875, 0.0205841064453125, -0.01190185546875, -0.033935546875, -0.0157470703125, 0.03521728515625, -0.0291900634765625, -0.0113372802734375, 0.025604248046875, -0.01480865478515625, -0.0389404296875, 0.0020656585693359