# %%
"""0  → very similar
1  → moderately similar
2  → completely different"""

from scipy.spatial import distance

vector1= [1,2]
vector2= [2,4]

result=distance.cosine(vector1,vector2)

print(result)
# Out:
# 0.0
